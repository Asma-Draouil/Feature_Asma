# %%
import pandas as pd
import re
from nltk.corpus import stopwords

import nltk

# %%
df = pd.read_csv("licence.csv")
df
# Out:
#                                            Objectifs  \
# 0  La licence en Science de Gestion – Parcours Ma...
# 1  La licence en Science de Gestion – Parcours Ma...
# 2  Le monde est devenu mathématique. La décision ...
# 3  La licence en Business Computing – ParcoursBus...
# 4  L’objectif est de former des consultants dotés...
#
#                                              Contenu  \
# 0  COMPTABILITE FISCALITE FINANCE :, Comptabilité...
# 1  SCIENCES DE GESTION :, Gestion, Economie, Comp...
# 2  MATHÉMATIQUES ET STATISTIQUES :, Analyse des d...
# 3  INFORMATIQUE & BI :\nSystèmes d’information, D...
# 4  INFORMATIQUE & BI :\nSystèmes d’information, D...
#
#                                          Compétences  \
# 0  Maîtriser les techniques d’élaboration des sup...
# 1  Analyser les évolutions de l’environnement des...
# 2  Aider les organisations à créer de la valeur o...
# 3  Maîtriser l’utilisation de l’outil informatiqu...
# 4  Concevoir et développer une solution décisionn...
#
#                                              Métiers  \
# 0  Comptable, Contrôleur de Gestion, Trésorier ou...
# 1  Chargé de Clientèle, Chef de Projet, Chef de P...
# 2  Analyste de Données, Chargé d’Études Actuariel...
# 3  Développeur, Testeur, Concepteur, Architecte S...
# 4  Consultant BI\nAnalyste / Consultant Décisionn...
#
#                                  Secteurs d’activité  \
# 0  Cabinets d’expertise comptable, Départements c...
# 1  Entreprises de services numériques, Entreprise...
# 2  Sociétés de services informatique, Éditeurs de...
# 3  Sociétés de services informatique Éditeurs de ...
# 4  Sociétés de services informatique\nÉditeurs de...
#
#                          Partenariats professionnels  \
# 0  > Entreprise de services numériques, >Sociétés...
# 1  > Agence de communication, > Sociétés de conse...
# 2  > Entreprises de services numériques, > Banque...
# 3  >Entreprises de services numériques > Banques ...
# 4  \n>Entreprises de services numériques\n> Banqu...
#
#                                           Semestre 1  \
# 0  Principes de gestion 1, Comptabilité financièr...
# 1  Principes de gestion 1, Comptabilité financièr...
# 2  Algèbre 1, Analyse 1, Base de données, Program...
# 3  Algorithmique et Structures de Données 1\nSyst...
# 4  Algorithmique et Structures de Données 1\nSyst...
#
#                                           Semestre 2  \
# 0  Principes de gestion 2, Comptabilité financièr...
# 1  Principes de gestion 2, Comptabilité financièr...
# 2  Algèbre 2, Analyse 2, Systèmes de gestion de b...
# 3  Algorithmique et Structures de Données 2\nFond...
# 4  Algorithmique et Structures de Données 2\nFond...
#
#                                           Semestre 3  \
# 0  Comptabilité intermédiaire I, Comptabilité de ...
# 1  Fondamentaux en management, Comptabilité de ge...
# 2  Algèbre 3, Analyse 3, Intelligence artificiell...
# 3  Programmation OO\nProgrammation Web 1\nConcept...
# 4  Programmation OO\nProgrammation Web 1\nConcept...
#
#                                           Semestre 4  \
# 0  Comptabilité intermédiaire II, Contrôle intern...
# 1  Fondamentaux de la GRH, Diagnostic financier, ...
# 2  Recherche opérationnelle, Analyse 4, Introduct...
# 3  Gestion des Opérations et de la logistique\nBu...
# 4  Gestion des Opérations et de la logistique\nBu...
#
#                                           Semestre 5  \
# 0  Comptabilité avancée, Cadre conceptuel et prés...
# 1  Théorie des organisations, Analyses quantitati...
# 2  Probabilités, Calcul différentiel, Mathématiqu...
# 3  Intégration des SI\nERP\nGénie Logiciel\nGesti...
# 4  Intégration des SI\nERP\nGénie Logiciel\nGesti...
#
#                                           Semestre 6
# 0  Comptabilité internationale : IFRS, Audit, Déc...
# 1  Management de l’innovation et entrepreneuriat,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
data_cleaned = df.copy()

# %%
parcours = [
    "Comptabilité", 
    "Management", 
    "Mathématiques Appliquées à l’Analyse des Données et à l’Aide à la Décision", 
    "Business Intelligence", 
    "Business Information Systems"
]
data_cleaned.insert(0, "Parcours", parcours[:len(data_cleaned)])
data_cleaned
# Out:
#                                             Parcours  \
# 0                                       Comptabilité
# 1                                         Management
# 2  Mathématiques Appliquées à l’Analyse des Donné...
# 3                              Business Intelligence
# 4                       Business Information Systems
#
#                                            Objectifs  \
# 0  La licence en Science de Gestion – Parcours Ma...
# 1  La licence en Science de Gestion – Parcours Ma...
# 2  Le monde est devenu mathématique. La décision ...
# 3  La licence en Business Computing – ParcoursBus...
# 4  L’objectif est de former des consultants dotés...
#
#                                              Contenu  \
# 0  COMPTABILITE FISCALITE FINANCE :, Comptabilité...
# 1  SCIENCES DE GESTION :, Gestion, Economie, Comp...
# 2  MATHÉMATIQUES ET STATISTIQUES :, Analyse des d...
# 3  INFORMATIQUE & BI :\nSystèmes d’information, D...
# 4  INFORMATIQUE & BI :\nSystèmes d’information, D...
#
#                                          Compétences  \
# 0  Maîtriser les techniques d’élaboration des sup...
# 1  Analyser les évolutions de l’environnement des...
# 2  Aider les organisations à créer de la valeur o...
# 3  Maîtriser l’utilisation de l’outil informatiqu...
# 4  Concevoir et développer une solution décisionn...
#
#                                              Métiers  \
# 0  Comptable, Contrôleur de Gestion, Trésorier ou...
# 1  Chargé de Clientèle, Chef de Projet, Chef de P...
# 2  Analyste de Données, Chargé d’Études Actuariel...
# 3  Développeur, Testeur, Concepteur, Architecte S...
# 4  Consultant BI\nAnalyste / Consultant Décisionn...
#
#                                  Secteurs d’activité  \
# 0  Cabinets d’expertise comptable, Départements c...
# 1  Entreprises de services numériques, Entreprise...
# 2  Sociétés de services informatique, Éditeurs de...
# 3  Sociétés de services informatique Éditeurs de ...
# 4  Sociétés de services informatique\nÉditeurs de...
#
#                          Partenariats professionnels  \
# 0  > Entreprise de services numériques, >Sociétés...
# 1  > Agence de communication, > Sociétés de conse...
# 2  > Entreprises de services numériques, > Banque...
# 3  >Entreprises de services numériques > Banques ...
# 4  \n>Entreprises de services numériques\n> Banqu...
#
#                                           Semestre 1  \
# 0  Principes de gestion 1, Comptabilité financièr...
# 1  Principes de gestion 1, Comptabilité financièr...
# 2  Algèbre 1, Analyse 1, Base de données, Program...
# 3  Algorithmique et Structures de Données 1\nSyst...
# 4  Algorithmique et Structures de Données 1\nSyst...
#
#                                           Semestre 2  \
# 0  Principes de gestion 2, Comptabilité financièr...
# 1  Principes de gestion 2, Comptabilité financièr...
# 2  Algèbre 2, Analyse 2, Systèmes de gestion de b...
# 3  Algorithmique et Structures de Données 2\nFond...
# 4  Algorithmique et Structures de Données 2\nFond...
#
#                                           Semestre 3  \
# 0  Comptabilité intermédiaire I, Comptabilité de ...
# 1  Fondamentaux en management, Comptabilité de ge...
# 2  Algèbre 3, Analyse 3, Intelligence artificiell...
# 3  Programmation OO\nProgrammation Web 1\nConcept...
# 4  Programmation OO\nProgrammation Web 1\nConcept...
#
#                                           Semestre 4  \
# 0  Comptabilité intermédiaire II, Contrôle intern...
# 1  Fondamentaux de la GRH, Diagnostic financier, ...
# 2  Recherche opérationnelle, Analyse 4, Introduct...
# 3  Gestion des Opérations et de la logistique\nBu...
# 4  Gestion des Opérations et de la logistique\nBu...
#
#                                           Semestre 5  \
# 0  Comptabilité avancée, Cadre conceptuel et prés...
# 1  Théorie des organisations, Analyses quantitati...
# 2  Probabilités, Calcul différentiel, Mathématiqu...
# 3  Intégration des SI\nERP\nGénie Logiciel\nGesti...
# 4  Intégration des SI\nERP\nGénie Logiciel\nGesti...
#
#                                           Semestre 6
# 0  Comptabilité internationale : IFRS, Audit, Déc...
# 1  Management de l’innovation et entrepreneuriat,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# Télécharger les ressources nécessaires pour NLTK
nltk.download('stopwords')


# Charger les stopwords en français
stop_words = set(stopwords.words('french'))

def nettoyer_colonne_avance(texte):
    if not isinstance(texte, str):  # Vérifie que la valeur est une chaîne
        return ''
    # Convertir en minuscules
    texte = texte.lower()
    # Remplacer les caractères spéciaux et ponctuations par des espaces
    texte = re.sub(r'[^\w\s]', ' ', texte)
    # Supprimer les espaces multiples
    texte = re.sub(r'\s+', ' ', texte).strip()
    # Supprimer les mots inutiles
    mots = texte.split()  # Divise le texte en mots avec split (pas de tokenisation)
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots)  # Recombine les mots filtrés
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Liste des colonnes textuelles
colonnes_textuelles = [
    "Objectifs", "Contenu", "Compétences", "Métiers", 
    "Secteurs d’activité", "Partenariats professionnels",
    "Semestre 1", "Semestre 2", "Semestre 3", "Semestre 4", "Semestre 5", "Semestre 6"
]

# Vérifiez quelles colonnes existent dans le DataFrame
colonnes_existe = [col for col in colonnes_textuelles if col in data_cleaned.columns]


for col in colonnes_existe:
    data_cleaned[col] = data_cleaned[col].fillna('').apply(nettoyer_colonne_avance)

# %%
data_cleaned = data_cleaned.fillna('')

# %%
data_cleaned.head()
# Out:
#                                             Parcours  \
# 0                                       Comptabilité
# 1                                         Management
# 2  Mathématiques Appliquées à l’Analyse des Donné...
# 3                              Business Intelligence
# 4                       Business Information Systems
#
#                                            Objectifs  \
# 0  licence science gestion parcours managementvis...
# 1  licence science gestion parcours managementvis...
# 2  monde devenu mathématique décision repose anal...
# 3  licence business computing parcoursbusiness in...
# 4  objectif former consultants dotés assise théor...
#
#                                              Contenu  \
# 0  comptabilite fiscalite finance comptabilité fi...
# 1  sciences gestion gestion economie comptabilité...
# 2  mathématiques statistiques analyse données opt...
# 3  informatique bi systèmes information développe...
# 4  informatique bi systèmes information développe...
#
#                                          Compétences  \
# 0  maîtriser techniques élaboration supports comm...
# 1  analyser évolutions environnement affaires ana...
# 2  aider organisations créer valeur innover leurs...
# 3  maîtriser utilisation outil informatique gesti...
# 4  concevoir développer solution décisionnelle an...
#
#                                              Métiers  \
# 0  comptable contrôleur gestion trésorier financi...
# 1  chargé clientèle chef projet chef produit mana...
# 2  analyste données chargé études actuarielles as...
# 3  développeur testeur concepteur architecte syst...
# 4  consultant bi analyste consultant décisionnel ...
#
#                                  Secteurs d’activité  \
# 0  cabinets expertise comptable départements comp...
# 1  entreprises services numériques entreprises in...
# 2  sociétés services informatique éditeurs logici...
# 3  sociétés services informatique éditeurs logici...
# 4  sociétés services informatique éditeurs logici...
#
#                          Partenariats professionnels  \
# 0  entreprise services numériques sociétés consei...
# 1  agence communication sociétés conseil entrepri...
# 2  entreprises services numériques banques assura...
# 3  entreprises services numériques banques assura...
# 4  entreprises services numériques banques assura...
#
#                                           Semestre 1  \
# 0  principes gestion 1 comptabilité financière 1 ...
# 1  principes gestion 1 comptabilité financière 1 ...
# 2  algèbre 1 analyse 1 base données programmation...
# 3  algorithmique structures données 1 systèmes ex...
# 4  algorithmique structures données 1 systèmes ex...
#
#                                           Semestre 2  \
# 0  principes gestion 2 comptabilité financière 2 ...
# 1  principes gestion 2 comptabilité financière 2 ...
# 2  algèbre 2 analyse 2 systèmes gestion bases don...
# 3  algorithmique structures données 2 fondements ...
# 4  algorithmique structures données 2 fondements ...
#
#                                           Semestre 3  \
# 0  comptabilité intermédiaire i comptabilité gest...
# 1  fondamentaux management comptabilité gestion f...
# 2  algèbre 3 analyse 3 intelligence artificielle ...
# 3  programmation oo programmation web 1 conceptio...
# 4  programmation oo programmation web 1 conceptio...
#
#                                           Semestre 4  \
# 0  comptabilité intermédiaire ii contrôle interne...
# 1  fondamentaux grh diagnostic financier gestion ...
# 2  recherche opérationnelle analyse 4 introductio...
# 3  gestion opérations logistique business process...
# 4  gestion opérations logistique business process...
#
#                                           Semestre 5  \
# 0  comptabilité avancée cadre conceptuel présenta...
# 1  théorie organisations analyses quantitatives q...
# 2  probabilités calcul différentiel mathématiques...
# 3  intégration si erp génie logiciel gestion proj...
# 4  intégration si erp génie logiciel gestion proj...
#
#                                           Semestre 6
# 0  comptabilité internationale ifrs audit décisio...
# 1  management innovation entrepreneuriat manageme...
# 2
# 3
# 4

# %%
# Sauvegarder les données nettoyées dans un nouveau fichier CSV
data_cleaned.to_csv("licence_cleaned.csv", index=False)

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')

# Appliquer la tokenisation à chaque cellule de toutes les colonnes
data_cleaned = data_cleaned.apply(lambda col: col.apply(word_tokenize))

# Vérifier les résultats
print(data_cleaned.head())
# Out:
#                                             Parcours  \
# 0                                     [Comptabilité]
# 1                                       [Management]
# 2  [Mathématiques, Appliquées, à, l, ’, Analyse, ...
# 3                           [Business, Intelligence]
# 4                   [Business, Information, Systems]
#
#                                            Objectifs  \
# 0  [licence, science, gestion, parcours, manageme...
# 1  [licence, science, gestion, parcours, manageme...
# 2  [monde, devenu, mathématique, décision, repose...
# 3  [licence, business, computing, parcoursbusines...
# 4  [objectif, former, consultants, dotés, assise,...
#
#                                              Contenu  \
# 0  [comptabilite, fiscalite, finance, comptabilit...
# 1  [sciences, gestion, gestion, economie, comptab...
# 2  [mathématiques, statistiques, analyse, données...
# 3  [informatique, bi, systèmes, information, déve...
# 4  [informatique, bi, systèmes, information, déve...
#
#                                          Compétences  \
# 0  [maîtriser, techniques, élaboration, supports,...
# 1  [analyser, évolutions, environnement, affaires...
# 2  [aider, organisations, créer, valeur, innover,...
# 3  [maîtriser, utilisation, outil, informatique, ...
# 4  [concevoir, développer, solution, décisionnell...
#
#                                              Métiers  \
# 0  [comptable, contrôleur, gestion, trésorier, fi...
# 1  [chargé, clientèle, chef, projet, chef, produi...
# 2  [analyste, données, chargé, études, actuariell...
# 3  [développeur, testeur, concepteur, architecte,...
# 4  [consultant, bi, analyste, consultant, décisio...
#
#                                  Secteurs d’activité  \
# 0  [cabinets, expertise, comptable, départements,...
# 1  [entreprises, services, numériques, entreprise...
# 2  [sociétés, services, informatique, éditeurs, l...
# 3  [sociétés, services, informatique, éditeurs, l...
# 4  [sociétés, services, informatique, éditeurs, l...
#
#                          Partenariats professionnels  \
# 0  [entreprise, services, numériques, sociétés, c...
# 1  [agence, communication, sociétés, conseil, ent...
# 2  [entreprises, services, numériques, banques, a...
# 3  [entreprises, services, numériques, banques, a...
# 4  [entreprises, services, numériques, banques, a...
#
#                                           Semestre 1  \
# 0  [principes, gestion, 1, comptabilité, financiè...
# 1  [principes, gestion, 1, comptabilité, financiè...
# 2  [algèbre, 1, analyse, 1, base, données, progra...
# 3  [algorithmique, structures, données, 1, systèm...
# 4  [algorithmique, structures, données, 1, systèm...
#
#                                           Semestre 2  \
# 0  [principes, gestion, 2, comptabilité, financiè...
# 1  [principes, gestion, 2, comptabilité, financiè...
# 2  [algèbre, 2, analyse, 2, systèmes, gestion, ba...
# 3  [algorithmique, structures, données, 2, fondem...
# 4  [algorithmique, structures, données, 2, fondem...
#
#                                           Semestre 3  \
# 0  [comptabilité, intermédiaire, i, comptabilité,...
# 1  [fondamentaux, management, comptabilité, gesti...
# 2  [algèbre, 3, analyse, 3, intelligence, artific...
# 3  [programmation, oo, programmation, web, 1, con...
# 4  [programmation, oo, programmation, web, 1, con...
#
#                                           Semestre 4  \
# 0  [comptabilité, intermédiaire, ii, contrôle, in...
# 1  [fondamentaux, grh, diagnostic, financier, ges...
# 2  [recherche, opérationnelle, analyse, 4, introd...
# 3  [gestion, opérations, logistique, business, pr...
# 4  [gestion, opérations, logistique, business, pr...
#
#                                           Semestre 5  \
# 0  [comptabilité, avancée, cadre, conceptuel, pré...
# 1  [théorie, organisations, analyses, quantitativ...
# 2  [probabilités, calcul, différentiel, mathémati...
# 3  [intégration, si, erp, génie, logiciel, gestio...
# 4  [intégration, si, erp, génie, logiciel, gestio...
#
#                                           Semestre 6
# 0  [comptabilité, internationale, ifrs, audit, dé...
# 1  [management, innovation, entrepreneuriat, mana...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Asma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.stem.snowball import FrenchStemmer

# Initialiser le stemmer pour le français
stemmer = FrenchStemmer()

# Exemple d'application du stemming sur des données tokenisées
data_cleaned = data_cleaned.applymap(
    lambda x: [stemmer.stem(word) for word in x] if isinstance(x, list) else x
)

# Vérifier les résultats
print(data_cleaned.head())
# Out:
#                                             Parcours  \
# 0                                         [comptabl]
# 1                                            [manag]
# 2  [mathémat, appliqu, à, l, ’, analys, de, don, ...
# 3                            [business, intelligent]
# 4                         [business, inform, system]
#
#                                            Objectifs  \
# 0  [licenc, scienc, gestion, parcour, managementv...
# 1  [licenc, scienc, gestion, parcour, managementv...
# 2  [mond, devenu, mathémat, décis, repos, analys,...
# 3  [licenc, business, computing, parcoursbusiness...
# 4  [object, form, consult, dot, assis, théoriqu, ...
#
#                                              Contenu  \
# 0  [comptabilit, fiscalit, financ, comptabl, fisc...
# 1  [scienc, gestion, gestion, econom, comptabl, f...
# 2  [mathémat, statist, analys, don, optimis, disc...
# 3  [informat, bi, system, inform, développ, infor...
# 4  [informat, bi, system, inform, développ, infor...
#
#                                          Compétences  \
# 0  [maîtris, techniqu, élabor, support, commun, c...
# 1  [analys, évolu, environ, affair, analys, don, ...
# 2  [aid, organis, cré, valeur, innov, leur, secte...
# 3  [maîtris, utilis, outil, informat, gestion, di...
# 4  [concevoir, développ, solut, décisionnel, anal...
#
#                                              Métiers  \
# 0  [comptabl, contrôleur, gestion, trésori, finan...
# 1  [charg, clientel, chef, projet, chef, produit,...
# 2  [analyst, don, charg, étud, actuariel, assur, ...
# 3  [développeur, testeur, concepteur, architect, ...
# 4  [consult, bi, analyst, consult, décisionnel, e...
#
#                                  Secteurs d’activité  \
# 0  [cabinet, expertis, comptabl, départ, comptabl...
# 1  [entrepris, servic, numer, entrepris, industri...
# 2  [societ, servic, informat, éditeur, logiciel, ...
# 3  [societ, servic, informat, éditeur, logiciel, ...
# 4  [societ, servic, informat, éditeur, logiciel, ...
#
#                          Partenariats professionnels  \
# 0  [entrepris, servic, numer, societ, conseil, en...
# 1  [agenc, commun, societ, conseil, entrepris, co...
# 2  [entrepris, servic, numer, banqu, assur, socie...
# 3  [entrepris, servic, numer, banqu, assur, oper,...
# 4  [entrepris, servic, numer, banqu, assur, oper,...
#
#                                           Semestre 1  \
# 0  [princip, gestion, 1, comptabl, financi, 1, mi...
# 1  [princip, gestion, 1, comptabl, financi, 1, mi...
# 2  [algebr, 1, analys, 1, bas, don, programm, ang...
# 3  [algorithm, structur, don, 1, system, exploit,...
# 4  [algorithm, structur, don, 1, system, exploit,...
#
#                                           Semestre 2  \
# 0  [princip, gestion, 2, comptabl, financi, 2, ma...
# 1  [princip, gestion, 2, comptabl, financi, 2, ma...
# 2  [algebr, 2, analys, 2, system, gestion, bas, d...
# 3  [algorithm, structur, don, 2, fond, réseau, in...
# 4  [algorithm, structur, don, 2, fond, réseau, in...
#
#                                           Semestre 3  \
# 0  [comptabl, intermédiair, i, comptabl, gestion,...
# 1  [fondamental, manag, comptabl, gestion, fondam...
# 2  [algebr, 3, analys, 3, intelligent, artificiel...
# 3  [programm, oo, programm, web, 1, concept, oo, ...
# 4  [programm, oo, programm, web, 1, concept, oo, ...
#
#                                           Semestre 4  \
# 0  [comptabl, intermédiair, ii, contrôl, intern, ...
# 1  [fondamental, grh, diagnostic, financi, gestio...
# 2  [recherch, opérationnel, analys, 4, introduct,...
# 3  [gestion, oper, logist, business, process, man...
# 4  [gestion, oper, logist, business, process, man...
#
#                                           Semestre 5  \
# 0  [comptabl, avanc, cadr, conceptuel, présent, é...
# 1  [théor, organis, analys, quantit, qualit, mana...
# 2  [probabl, calcul, différentiel, mathémat, disc...
# 3  [integr, si, erp, gen, logiciel, gestion, proj...
# 4  [integr, si, erp, gen, logiciel, gestion, proj...
#
#                                           Semestre 6
# 0  [comptabl, international, ifr, audit, décis, f...
# 1  [manag, innov, entrepreneuriat, manag, transfo...
# 2                                                 []
# 3                                                 []
# 4                                                 []
# C:\Users\Asma\AppData\Local\Temp\ipykernel_16176\2949108165.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_cleaned = data_cleaned.applymap(

# %%
#Vectorisation
#TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer

# Exclure la colonne 'parcours'
colonnes_a_vectoriser = data_cleaned.drop(columns=['Parcours']).columns

# Dictionnaire pour stocker les résultats vectorisés
vecteurs = {}

# Vectorisation des colonnes
tfidf_vectorizer = TfidfVectorizer()

for col in colonnes_a_vectoriser:
    # Appliquer TF-IDF à chaque colonne
    vecteurs[col] = tfidf_vectorizer.fit_transform(data_cleaned[col].astype(str))
    print(f"Colonne '{col}' vectorisée avec {len(tfidf_vectorizer.get_feature_names_out())} termes.")

# Combiner tous les vecteurs dans une seule matrice
from scipy.sparse import hstack

vecteurs_combines = hstack(list(vecteurs.values()))

# Afficher la dimension de la matrice finale
print(f"Dimensions de la matrice combinée : {vecteurs_combines.shape}")
# Out:
# Colonne 'Objectifs' vectorisée avec 159 termes.
# Colonne 'Contenu' vectorisée avec 113 termes.
# Colonne 'Compétences' vectorisée avec 138 termes.
# Colonne 'Métiers' vectorisée avec 69 termes.
# Colonne 'Secteurs d’activité' vectorisée avec 24 termes.
# Colonne 'Partenariats professionnels' vectorisée avec 14 termes.
# Colonne 'Semestre 1' vectorisée avec 43 termes.
# Colonne 'Semestre 2' vectorisée avec 47 termes.
# Colonne 'Semestre 3' vectorisée avec 48 termes.
# Colonne 'Semestre 4' vectorisée avec 62 termes.
# Colonne 'Semestre 5' vectorisée avec 63 termes.
# Colonne 'Semestre 6' vectorisée avec 32 termes.
# Dimensions de la matrice combinée : (5, 812)

# %% [markdown]
# ## todo visualisation avec t-SNE ou PCA
# # gensim installation

# %%
from gensim.models import Word2Vec
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from gensim.models import Word2Vec
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'gensim'
