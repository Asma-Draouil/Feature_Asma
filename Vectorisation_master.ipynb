# %% [markdown]
# <a href="https://colab.research.google.com/github/Asma-Draouil/Feature_Asma/blob/main/Vectorisation_master.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# %%
url="https://raw.githubusercontent.com/Asma-Draouil/Feature_Asma/refs/heads/main/Nouveau%20dossier/masters.csv"
df = pd.read_csv(url)

# %%
data_cleaned = df.copy()

# %%
data_cleaned = data_cleaned.drop(index=2)

# %%
data_cleaned = data_cleaned.reset_index(drop=True)
data_cleaned
# Out:
#                                            Objectifs  \
# 0  Le Master Professionnel en Marketing Digital v...
# 1  Le Master Professionnel en Comptabilité, Contr...
# 2  > Entreprises de services numériques\n> Opérat...
# 3  Le Master Professionnel en Gestion Actuarielle...
# 4  Le Master Professionnel en Finance Digitale vi...
# 5  Le Master Professionnel en Business Analytics ...
#
#                                              Contenu  \
# 0                                                NaN
# 1  UNITÉS D’ENSEIGNEMENT FONDAMENTALES:Normes et ...
# 2  MANAGEMENT : Business Process Management, Cond...
# 3  ACTUARIAT :Introduction à l’Actuariat, Actuari...
# 4  FINANCE: Analyse Financière Approfondie, Asset...
# 5  DATA SCIENCE ET INTELLIGENCE ARTIFICIELLE : Ma...
#
#                                          Compétences  \
# 0  Préparer les contenus de la communication (ben...
# 1  Maîtriser parfaitement la technique comptable ...
# 2  Anticiper et gérer les changements liés à la t...
# 3  Adapter les outils de traitement statistique d...
# 4  Analyser et gérer les risques financiers par l...
# 5  Conceptualiser, modéliser et analyser des donn...
#
#                                              Métiers  \
# 0  Chargé de la Communication Web : Directeur de ...
# 1  Cadre opérationnel et supérieur, Auditeur et c...
# 2  Responsable de la Transformation Digital : Chi...
# 3  Actuaire, Data Scientist / Data Analyst, Respo...
# 4  Analyste Financier, Chef de Projet FinTech, Co...
# 5  Data Analyst\nBusiness Analyst\nData Scientist...
#
#                                  Secteurs d’activité  \
# 0  Entreprises de services numériques\nSociétés d...
# 1  Entreprises publiques ou privées non financièr...
# 2  Entreprises de services numériques\nSociétés d...
# 3  Banques, Assurances & Bourses, Organisme d’Étu...
# 4  Secteur Bancaire et des Assurances, Organismes...
# 5  Sociétés de services informatiques\nOpérateurs...
#
#                          Partenariats professionnels  \
# 0  Agences de communication\nSociétés de conseil\...
# 1  > Ordre des Experts Comptables                ...
# 2  Entreprises de services numériques\nOpérateur ...
# 3  > Association Tunisienne des Actuaires, > Banq...
# 4     > Banques et Assurances, > Entreprises Fintech
# 5  Business & Decision Tunisie | Entreprises de s...
#
#                              Période d'Harmonisation  \
# 0  Probabilité et Statistique\nAnalyse Statistiqu...
# 1  Normes de présentation Normes relatives aux in...
# 2  Probabilités et Analyse Statistique\nAtelier d...
# 3  Intégration et Probabilité, Analyse numérique,...
# 4  Intelligence artificielle en finance, Analyse ...
# 5  Principes de gestion\nFondamentaux mathématiqu...
#
#                                           Semestre 1  \
# 0  Management stratégique et transition digitale\...
# 1  Commissariat aux comptes Normes internationale...
# 2  Architecture des systèmes d’information\nManag...
# 3  Modèles linéaires généralisés, Séries temporel...
# 4  Big Data, Inclusion financière, Finance intern...
# 5  Gestion de projets et conduite au changement\n...
#
#                                           Semestre 2  \
# 0  Web marketing\nMarketing mobile\nTechnologie W...
# 1  Comptabilité : Fusion et Consolidation Gestion...
# 2  Management des projets et conduite du changeme...
# 3  Modèles aléatoires pour l’actuariat et la fina...
# 4  Datamining, Trading à haute fréquence (THF), T...
# 5  Management stratégique\nPilotage de projets dé...
#
#                                           Semestre 3  \
# 0  Web analyses\nAnalyse de données marketing\ne-...
# 1  Cas de synthèse en comptabilité Cas de synthès...
# 2  SI décisionnels et Big Data\nSolution SI : ERP...
# 3               Stage de 6 mois  en Entreprise (SFE)
# 4          Stage de fin d’études L’accès au Master :
# 5  Business process management\nDroit des données...
#
#                                           Semestre 4  \
# 0                          Stage en entreprise (PFE)
# 1                                                NaN
# 2  Probabilités et analyse statistique\nAtelier d...
# 3                                                NaN
# 4                                                NaN
# 5    Atelier BI\nStage de 6 mois en Entreprise (SFE)
#
#                              Période d’Harmonisation
# 0  Probabilité et statistique\nAnalyse statistiqu...
# 1                                                NaN
# 2                          Stage en entreprise (PFE)
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
data_cleaned.loc[2, "Objectifs"] = """
Le Master Professionnel en Management Digital et Systèmes d’Information permet de former des spécialistes en
management des systèmes d’information et intégration des technologies de l’information et de la communication capables
d’accompagner les entreprises dans leurs processus de transformation digitale. Le Master Professionnel en Management
digital & systèmes d’information est disponible en double diplôme en International Management avec IMT-BS et en
Management et Stratégie d’Entreprise avec Ascencia Business School.
"""

# %%
data_cleaned.loc[0, "Contenu"]=""" DIGITAL : Webmarketing, E-business, E-communication, Infographie et Web Design, Web analyses, etc.
MARKETING : Marketing Stratégique / Opérationnel, Recherche Marketing, Analyse du comportement du Cyberconsommateur.
SOFT SKILLS : Séminaires, Développement Personnel, Gestion de projet, Langues, etc.
Projet Professionnel : Tages, PFE, Projets Intégrés, Visites d’entreprises, etc."""

# %%
parcours = [
    "marketing digital",
    "Comptabilité, Contrôle, Audit",
    "Management Digital et Systèmes d’Information",
    "Gestion Actuarielle et Modélisation Mathématique",
    "Finance Digitale",
    "Business Analytics"
]
data_cleaned.insert(0, "Parcours", parcours[:len(data_cleaned)])

# %%
# Télécharger les ressources nécessaires pour NLTK
nltk.download('stopwords')


# Charger les stopwords en français
stop_words = set(stopwords.words('french'))

def nettoyer_colonne_avance(texte):
    if not isinstance(texte, str):  # Vérifie que la valeur est une chaîne
        return ''
    # Convertir en minuscules
    texte = texte.lower()
    # Remplacer les caractères spéciaux et ponctuations par des espaces
    texte = re.sub(r'[^\w\s]', ' ', texte)
    # Supprimer les espaces multiples
    texte = re.sub(r'\s+', ' ', texte).strip()
    # Supprimer les mots inutiles
    mots = texte.split()  # Divise le texte en mots avec split (pas de tokenisation)
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots)  # Recombine les mots filtrés
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Liste des colonnes textuelles
colonnes_textuelles = [
    "Objectifs", "Contenu", "Compétences", "Métiers",
    "Secteurs d’activité", "Partenariats professionnels",
    "Semestre 1", "Semestre 2", "Semestre 3", "Semestre 4", "Semestre 5", "Semestre 6"
]

# Vérifiez quelles colonnes existent dans le DataFrame
colonnes_existe = [col for col in colonnes_textuelles if col in data_cleaned.columns]


for col in colonnes_existe:
    data_cleaned[col] = data_cleaned[col].fillna('').apply(nettoyer_colonne_avance)

# %%
data_cleaned = data_cleaned.fillna('')

# %%
# Sauvegarder les données nettoyées dans un nouveau fichier CSV
data_cleaned.to_csv("master_cleaned.csv", index=False)

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')

# Appliquer la tokenisation à chaque cellule de toutes les colonnes
data_cleaned = data_cleaned.apply(lambda col: col.apply(word_tokenize))

# Vérifier les résultats
print(data_cleaned.head())
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                             Parcours  \
# 0                               [marketing, digital]
# 1              [Comptabilité, ,, Contrôle, ,, Audit]
# 2  [Management, Digital, et, Systèmes, d, ’, Info...
# 3  [Gestion, Actuarielle, et, Modélisation, Mathé...
# 4                                [Finance, Digitale]
#
#                                            Objectifs  \
# 0  [master, professionnel, marketing, digital, vi...
# 1  [master, professionnel, comptabilité, contrôle...
# 2  [master, professionnel, management, digital, s...
# 3  [master, professionnel, gestion, actuarielle, ...
# 4  [master, professionnel, finance, digitale, vis...
#
#                                              Contenu  \
# 0  [digital, webmarketing, e, business, e, commun...
# 1  [unités, enseignement, fondamentales, normes, ...
# 2  [management, business, process, management, co...
# 3  [actuariat, introduction, actuariat, actuariat...
# 4  [finance, analyse, financière, approfondie, as...
#
#                                          Compétences  \
# 0  [préparer, contenus, communication, benchmark,...
# 1  [maîtriser, parfaitement, technique, comptable...
# 2  [anticiper, gérer, changements, liés, transfor...
# 3  [adapter, outils, traitement, statistique, don...
# 4  [analyser, gérer, risques, financiers, mise, a...
#
#                                              Métiers  \
# 0  [chargé, communication, web, directeur, commun...
# 1  [cadre, opérationnel, supérieur, auditeur, con...
# 2  [responsable, transformation, digital, chief, ...
# 3  [actuaire, data, scientist, data, analyst, res...
# 4  [analyste, financier, chef, projet, fintech, c...
#
#                                  Secteurs d’activité  \
# 0  [entreprises, services, numériques, sociétés, ...
# 1  [entreprises, publiques, privées, non, financi...
# 2  [entreprises, services, numériques, sociétés, ...
# 3  [banques, assurances, bourses, organisme, étud...
# 4  [secteur, bancaire, assurances, organismes, pl...
#
#                          Partenariats professionnels  \
# 0  [agences, communication, sociétés, conseil, ba...
# 1  [ordre, experts, comptables, tunisie, compagni...
# 2  [entreprises, services, numériques, opérateur,...
# 3  [association, tunisienne, actuaires, banques, ...
# 4        [banques, assurances, entreprises, fintech]
#
#                              Période d'Harmonisation  \
# 0  [Probabilité, et, Statistique, Analyse, Statis...
# 1  [Normes, de, présentation, Normes, relatives, ...
# 2  [Probabilités, et, Analyse, Statistique, Ateli...
# 3  [Intégration, et, Probabilité, ,, Analyse, num...
# 4  [Intelligence, artificielle, en, finance, ,, A...
#
#                                           Semestre 1  \
# 0  [management, stratégique, transition, digitale...
# 1  [commissariat, comptes, normes, internationale...
# 2  [architecture, systèmes, information, manageme...
# 3  [modèles, linéaires, généralisés, séries, temp...
# 4  [big, data, inclusion, financière, finance, in...
#
#                                           Semestre 2  \
# 0  [web, marketing, marketing, mobile, technologi...
# 1  [comptabilité, fusion, consolidation, gestion,...
# 2  [management, projets, conduite, changement, ve...
# 3  [modèles, aléatoires, actuariat, finance, actu...
# 4  [datamining, trading, haute, fréquence, thf, t...
#
#                                           Semestre 3  \
# 0  [web, analyses, analyse, données, marketing, e...
# 1  [cas, synthèse, comptabilité, cas, synthèse, a...
# 2  [si, décisionnels, big, data, solution, si, er...
# 3                  [stage, 6, mois, entreprise, sfe]
# 4                [stage, fin, études, accès, master]
#
#                                           Semestre 4  \
# 0                           [stage, entreprise, pfe]
# 1                                                 []
# 2  [probabilités, analyse, statistique, atelier, ...
# 3                                                 []
# 4                                                 []
#
#                              Période d’Harmonisation
# 0  [Probabilité, et, statistique, Analyse, statis...
# 1                                                 []
# 2                 [Stage, en, entreprise, (, PFE, )]
# 3                                                 []
# 4                                                 []

# %%
from nltk.stem.snowball import FrenchStemmer

# Initialiser le stemmer pour le français
stemmer = FrenchStemmer()

# Exemple d'application du stemming sur des données tokenisées
data_cleaned = data_cleaned.applymap(
    lambda x: [stemmer.stem(word) for word in x] if isinstance(x, list) else x
)

# Vérifier les résultats
print(data_cleaned.head())
# Out:
#                                       Parcours  \
# 0                         [marketing, digital]
# 1             [comptabl, ,, contrôl, ,, audit]
# 2   [manag, digital, et, system, d, ’, inform]
# 3  [gestion, actuariel, et, modélis, mathémat]
# 4                            [financ, digital]
#
#                                            Objectifs  \
# 0  [mast, professionnel, marketing, digital, vis,...
# 1  [mast, professionnel, comptabl, contrôl, audit...
# 2  [mast, professionnel, manag, digital, system, ...
# 3  [mast, professionnel, gestion, actuariel, modé...
# 4  [mast, professionnel, financ, digital, vis, fo...
#
#                                              Contenu  \
# 0  [digital, webmarketing, e, business, e, commun...
# 1  [unit, enseign, fondamental, norm, difficult, ...
# 2  [manag, business, process, manag, conduit, cha...
# 3  [actuariat, introduct, actuariat, actuariat, v...
# 4  [financ, analys, financi, approfond, asset, li...
#
#                                          Compétences  \
# 0  [prépar, contenus, commun, benchmark, veil, re...
# 1  [maîtris, parfait, techniqu, comptabl, nationa...
# 2  [anticip, ger, chang, li, transform, digital, ...
# 3  [adapt, outil, trait, statist, don, modélis, m...
# 4  [analys, ger, risqu, financi, mis, appliqu, mo...
#
#                                              Métiers  \
# 0  [charg, commun, web, directeur, commun, consul...
# 1  [cadr, opérationnel, supérieur, auditeur, cons...
# 2  [respons, transform, digital, chief, digital, ...
# 3  [actuair, dat, scientist, dat, analyst, respon...
# 4  [analyst, financi, chef, projet, fintech, cons...
#
#                                  Secteurs d’activité  \
# 0  [entrepris, servic, numer, societ, conseil, ag...
# 1  [entrepris, publiqu, priv, non, financi, insti...
# 2  [entrepris, servic, numer, societ, conseil, ba...
# 3  [banqu, assur, bours, organ, étud, sondag, cai...
# 4  [secteur, bancair, assur, organ, plac, gestion...
#
#                          Partenariats professionnels  \
# 0  [agenc, commun, societ, conseil, banqu, assur,...
# 1  [ordre, expert, comptabl, tunis, compagn, comp...
# 2  [entrepris, servic, numer, oper, télécommun, b...
# 3          [associ, tunisien, actuair, banqu, assur]
# 4                 [banqu, assur, entrepris, fintech]
#
#                              Période d'Harmonisation  \
# 0  [probabl, et, statist, analys, statist, analys...
# 1  [norm, de, présent, norm, relat, aux, instrume...
# 2  [probabl, et, analys, statist, ateli, de, prog...
# 3  [integr, et, probabl, ,, analys, numer, ,, ate...
# 4  [intelligent, artificiel, en, financ, ,, analy...
#
#                                           Semestre 1  \
# 0  [manag, strateg, transit, digital, manag, proj...
# 1  [commissariat, compt, norm, international, rel...
# 2  [architectur, system, inform, manag, system, i...
# 3  [model, linéair, généralis, ser, temporel, fon...
# 4  [big, dat, inclus, financi, financ, internatio...
#
#                                           Semestre 2  \
# 0  [web, marketing, marketing, mobil, technolog, ...
# 1  [comptabl, fusion, consolid, gestion, jurid, f...
# 2  [manag, projet, conduit, chang, veil, intellig...
# 3  [model, aléatoir, actuariat, financ, actuariat...
# 4  [datamining, trading, haut, fréquenc, thf, tec...
#
#                                           Semestre 3  \
# 0  [web, analys, analys, don, marketing, e, merch...
# 1  [cas, synthes, comptabl, cas, synthes, audit, ...
# 2  [si, décisionnel, big, dat, solut, si, erp, cr...
# 3                    [stag, 6, mois, entrepris, sfe]
# 4                     [stag, fin, étud, acces, mast]
#
#                                           Semestre 4  \
# 0                             [stag, entrepris, pfe]
# 1                                                 []
# 2  [probabl, analys, statist, ateli, programm, in...
# 3                                                 []
# 4                                                 []
#
#                              Période d’Harmonisation
# 0  [probabl, et, statist, analys, statist, analys...
# 1                                                 []
# 2                   [stag, en, entrepris, (, pfe, )]
# 3                                                 []
# 4                                                 []
# <ipython-input-16-3478052cfef9>:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data_cleaned = data_cleaned.applymap(

# %%
#Vectorisation
#TF-IDF

from sklearn.feature_extraction.text import TfidfVectorizer

# Exclure la colonne 'parcours'
colonnes_a_vectoriser = data_cleaned.drop(columns=['Parcours']).columns

# Dictionnaire pour stocker les résultats vectorisés
vecteurs = {}

# Vectorisation des colonnes
tfidf_vectorizer = TfidfVectorizer()

for col in colonnes_a_vectoriser:
    # Appliquer TF-IDF à chaque colonne
    vecteurs[col] = tfidf_vectorizer.fit_transform(data_cleaned[col].astype(str))
    print(f"Colonne '{col}' vectorisée avec {len(tfidf_vectorizer.get_feature_names_out())} termes.")

# Combiner tous les vecteurs dans une seule matrice
from scipy.sparse import hstack

vecteurs_combines = hstack(list(vecteurs.values()))

# Afficher la dimension de la matrice finale
print(f"Dimensions de la matrice combinée : {vecteurs_combines.shape}")
# Out:
# Colonne 'Objectifs' vectorisée avec 112 termes.
# Colonne 'Contenu' vectorisée avec 115 termes.
# Colonne 'Compétences' vectorisée avec 147 termes.
# Colonne 'Métiers' vectorisée avec 80 termes.
# Colonne 'Secteurs d’activité' vectorisée avec 44 termes.
# Colonne 'Partenariats professionnels' vectorisée avec 27 termes.
# Colonne 'Période d'Harmonisation' vectorisée avec 86 termes.
# Colonne 'Semestre 1' vectorisée avec 104 termes.
# Colonne 'Semestre 2' vectorisée avec 120 termes.
# Colonne 'Semestre 3' vectorisée avec 78 termes.
# Colonne 'Semestre 4' vectorisée avec 19 termes.
# Colonne 'Période d’Harmonisation' vectorisée avec 14 termes.
# Dimensions de la matrice combinée : (6, 946)

# %%
# Visualisation avec t-SNE
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=42, perplexity=1, n_iter=1000)
data_tsne = tsne.fit_transform(vecteurs_combines.toarray())

# Créer un DataFrame pour visualisation
import matplotlib.pyplot as plt
df_tsne = pd.DataFrame(data_tsne, columns=['Dimension 1', 'Dimension 2'])
df_tsne['Parcours'] = data_cleaned['Parcours']

# Visualisation
plt.figure(figsize=(12, 8))
for parcours in df_tsne['Parcours'].unique():
    subset = df_tsne[df_tsne['Parcours'] == parcours]
    plt.scatter(subset['Dimension 1'], subset['Dimension 2'], label=parcours, alpha=0.7)

plt.title("Visualisation des Parcours avec t-SNE")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2a53859012b8> in <cell line: 13>()
#      11 # Visualisation
#      12 plt.figure(figsize=(12, 8))
# ---> 13 for parcours in df_tsne['Parcours'].unique():
#      14     subset = df_tsne[df_tsne['Parcours'] == parcours]
#      15     plt.scatter(subset['Dimension 1'], subset['Dimension 2'], label=parcours, alpha=0.7)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in unique(self)
#    2405         Categories (3, object): ['a' < 'b' < 'c']
#    2406         """
# -> 2407         return super().unique()
#    2408
#    2409     @overload
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in unique(self)
#    1023             result = values.unique()
#    1024         else:
# -> 1025             result = algorithms.unique1d(values)
#    1026         return result
#    1027
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique(values)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#     402
#     403
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique_with_mask(values, mask)
#     438     table = hashtable(len(values))
#     439     if mask is None:
# --> 440         uniques = table.unique(values)
#     441         uniques = _reconstruct_data(uniques, original.dtype, original)
#     442         return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# Visualisation avec PCA (Réduction dimensionnelle )
from sklearn.decomposition import PCA

pca = PCA(n_components=2, random_state=42)
data_pca = pca.fit_transform(vecteurs_combines.toarray())

# Créer un DataFrame pour visualisation
df_pca = pd.DataFrame(data_pca, columns=['Dimension 1', 'Dimension 2'])
df_pca['Parcours'] = data_cleaned['Parcours']

# Visualisation
plt.figure(figsize=(12, 8))
for parcours in df_pca['Parcours'].unique():
    subset = df_pca[df_pca['Parcours'] == parcours]
    plt.scatter(subset['Dimension 1'], subset['Dimension 2'], label=parcours, alpha=0.7)

plt.title("Visualisation des Parcours avec PCA")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-e449feb22d77> in <cell line: 13>()
#      11 # Visualisation
#      12 plt.figure(figsize=(12, 8))
# ---> 13 for parcours in df_pca['Parcours'].unique():
#      14     subset = df_pca[df_pca['Parcours'] == parcours]
#      15     plt.scatter(subset['Dimension 1'], subset['Dimension 2'], label=parcours, alpha=0.7)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in unique(self)
#    2405         Categories (3, object): ['a' < 'b' < 'c']
#    2406         """
# -> 2407         return super().unique()
#    2408
#    2409     @overload
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in unique(self)
#    1023             result = values.unique()
#    1024         else:
# -> 1025             result = algorithms.unique1d(values)
#    1026         return result
#    1027
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique(values)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#     402
#     403
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique_with_mask(values, mask)
#     438     table = hashtable(len(values))
#     439     if mask is None:
# --> 440         uniques = table.unique(values)
#     441         uniques = _reconstruct_data(uniques, original.dtype, original)
#     442         return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
#Vectorisation avec words embedding

import gensim.downloader as api
import numpy as np
from scipy.sparse import hstack

# Charger le modèle Word2Vec pré-entraîné
word2vec_model = api.load("word2vec-google-news-300")

# Remplacer les valeurs manquantes par une chaîne vide et convertir toutes les colonnes en chaînes
data_cleaned = data_cleaned.fillna('').astype(str)

# Sélectionner toutes les colonnes à vectoriser
colonnes_a_vectoriser = data_cleaned.columns

# Fonction pour vectoriser un texte avec Word2Vec
def vectorize_text(text, model):
    words = text.split()  # Diviser le texte en mots
    vectors = []

    for word in words:
        if word in model:  # Si le mot existe dans le vocabulaire du modèle
            vectors.append(model[word])
        else:
            vectors.append(np.zeros(300))  # Vecteur nul pour les mots inconnus

    # Moyenne des vecteurs de mots pour obtenir un seul vecteur
    if len(vectors) > 0:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(300)  # Retourner un vecteur nul si le texte est vide

# Vectoriser chaque colonne et convertir en matrice 2D
vecteurs = {}
for col in colonnes_a_vectoriser:
    vecteurs[col] = np.array([vectorize_text(str(text), word2vec_model) for text in data_cleaned[col]])

# Convertir chaque tableau 2D pour compatibilité avec hstack
matrices = [np.array(vecteurs[col]) for col in colonnes_a_vectoriser]

# Combiner les matrices horizontalement
vecteurs_combines = np.hstack(matrices)

# Afficher les dimensions de la matrice finale
print(f"Dimensions de la matrice combinée : {vecteurs_combines.shape}")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Dimensions de la matrice combinée : (6, 3900)

# %%
# Visualisation avec t-SNE
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Réduction de dimensions avec t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=4, n_iter=1000)
vecteurs_tsne = tsne.fit_transform(vecteurs_combines_embedding)

# Visualisation avec t-SNE
plt.figure(figsize=(8, 6))
plt.scatter(vecteurs_tsne[:, 0], vecteurs_tsne[:, 1], alpha=0.7, s=20, c='green')
plt.title("Visualisation des données avec t-SNE")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.show()

# %%
# Visualisation avec PCA
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Réduction de dimensions avec PCA
pca = PCA(n_components=2)  # Réduire à 2 dimensions
vecteurs_pca = pca.fit_transform(vecteurs_combines_embedding)

# Visualisation avec PCA
plt.figure(figsize=(8, 6))
plt.scatter(vecteurs_pca[:, 0], vecteurs_pca[:, 1], alpha=0.7, s=20, c='blue')
plt.title("Visualisation des données avec PCA")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.show()
